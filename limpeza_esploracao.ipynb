# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
baseDPE = pd.read_csv("C:/Users/conta/Desktop/Python Dados Rio de Janeiro/BaseDPEvolucaoMensalCisp.csv", sep=';')
baseEstado_ano = pd.read_csv("C:/Users/conta/Desktop/Python Dados Rio de Janeiro/BaseEstadoTaxaAno.csv", sep=';')
baseEstado_mes = pd.read_csv("C:/Users/conta/Desktop/Python Dados Rio de Janeiro/BaseEstadoTaxaMes.csv", sep=';')
AISPpor_regiao = pd.read_csv("C:/Users/conta/Desktop/Python Dados Rio de Janeiro/AispPorRegiao.csv", sep=';')
#RelacaoRISP_AISP_CISP = pd.read_csv("C:/Users/conta/Desktop/Python Dados Rio de Janeiro/Relacao_RISPxAISPxCISP.csv", sep=';')

# %%
baseDPE.shape
# Out:
# (35670, 63)

# %%
baseDPE['ano'] = pd.to_datetime(baseDPE['ano'])
baseDPE['mes'] = pd.to_datetime(baseDPE['mes'])
baseEstado_ano['ano'] = pd.to_datetime(baseEstado_ano['ano'])
baseEstado_mes['mes'] = pd.to_datetime(baseEstado_mes['mes']).dt.month

# %%
baseEstado_mes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ano                         264 non-null    int64
#  1   mes                         264 non-null    datetime64[ns]
#  2   mes_ano                     264 non-null    object
#  3   hom_doloso                  264 non-null    object
#  4   lesao_corp_morte            264 non-null    object
#  5   latrocinio                  264 non-null    object
#  6   cvli                        264 non-null    object
#  7   hom_por_interv_policial     264 non-null    object
#  8   letalidade_violenta         264 non-null    object
#  9   tentat_hom                  264 non-null    object
#  10  lesao_corp_dolosa           264 non-null    object
#  11  estupro                     264 non-null    object
#  12  hom_culposo                 264 non-null    object
# ...

# %%
(baseEstado_ano['ano']).info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21 entries, 0 to 20
# Series name: ano
# Non-Null Count  Dtype
# --------------  -----
# 21 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 300.0 bytes

# %%
colunas_para_apagar = ['ano', 'mes_ano', 'fase']
baseEstado_mes = baseEstado_mes.drop(columns=colunas_para_apagar)

# %%
baseEstado_mes.head()
# Out:
#    mes hom_doloso lesao_corp_morte latrocinio  cvli hom_por_interv_policial  \
# 0    1       4,01             0,04       0,14  4,19                    0,61
# 1    2       3,97             0,03       0,08  4,08                    0,76
# 2    3       4,17             0,03       0,11  4,32                    0,77
# 3    4       3,98             0,07        0,1  4,15                    0,85
# 4    5       4,08             0,04       0,14  4,25                    0,65
#
#   letalidade_violenta tentat_hom lesao_corp_dolosa estupro  ... aaapai  cmp  \
# 0                 4,8       2,48             46,94    1,67  ...    NaN  NaN
# 1                4,83       2,46             48,32     1,5  ...    NaN  NaN
# 2                5,08       2,26             47,43    1,61  ...    NaN  NaN
# 3                   5       2,02             43,84    1,46  ...    NaN  NaN
# 4                4,91       2,59             39,77    1,29  ...    NaN  NaN
#
# ...

# %%
df_unido = pd.merge(baseDPE, baseEstado_mes, left_on='mes', right_on='mes', how='inner')
df_unido = pd.merge(df_unido, baseEstado_ano, left_on='ano', right_on='ano', how='inner')

df_unido.head()
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 4     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso_x  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0             0  ...  NaN   NaN  467,97                  32,33
# 1             0  ...  NaN   NaN  467,97                  32,33
# 2             0  ...  NaN   NaN  467,97                  32,33
# 3             0  ...  NaN   NaN  467,97                  32,33
# 4             0  ...  NaN   NaN  467,97                  32,33
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0             10,95             0,36                        NaN
# ...

# %%
dados_ausentes = df_unido.isnull().sum()

print(dados_ausentes)
# Out:
# cisp                     0
# mes                      0
# ano                      0
# mes_ano                  0
# aisp                     0
#                         ..
# pessoas_desaparecidas    0
# encontro_cadaver         0
# encontro_ossada          0
# registro_ocorrencias     0
# fase_y                   0
# Length: 168, dtype: int64

# %%
colunas_para_apagar = ['pol_militares_mortos_serv', 'pol_civis_mortos_serv' ]
df_unido = df_unido.drop(columns=colunas_para_apagar)

# %%
plt.Figure(figsize=(10, 6))
plt.barh(df_unido['ano'],  df_unido[''])

# %%
df_unido.head()
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 4     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso_x  ...  apf  aaapai  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0             0  ...  NaN     NaN  NaN   NaN  467,97                  32,33
# 1             0  ...  NaN     NaN  NaN   NaN  467,97                  32,33
# 2             0  ...  NaN     NaN  NaN   NaN  467,97                  32,33
# 3             0  ...  NaN     NaN  NaN   NaN  467,97                  32,33
# 4             0  ...  NaN     NaN  NaN   NaN  467,97                  32,33
#
# ...
