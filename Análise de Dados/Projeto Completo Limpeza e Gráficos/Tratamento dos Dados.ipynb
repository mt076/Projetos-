# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
clinicos = pd.read_csv('dados_clinicos.csv', sep=';' , encoding='latin-1')

# %%
pacientes = pd.read_csv('dados_pacientes.csv', sep=';' , encoding='latin-1')

# %%
regiao = pd.read_csv('estado_regiao.csv', sep=';' , encoding='latin-1')

# %%
clinicos.head()
# Out:
#    id_cliente   peso  colesterol     genero
# 0           1  102.0         111  Masculino
# 1           2  115.0         135  Masculino
# 2           3  115.0         136  Masculino
# 3           4  140.0         167   Feminino
# 4           5  130.0         158  Masculino

# %%
pacientes.rename(columns={'ï»¿id_cliente': 'id_cliente'}, inplace=True)

# %%
pacientes.head()
# Out:
#    id_cliente  idade             classe_trabalho              escolaridade  \
# 0           1     39           Servidor PÃºblico    Ensino MÃ©dio Completo
# 1           2     50                   AutÃ´nomo       Superior Incompleto
# 2           3     38  FuncionÃ¡rio Setor Privado  Ensino MÃ©dio Incompleto
# 3           4     53  FuncionÃ¡rio Setor Privado  Ensino MÃ©dio Incompleto
# 4           5     28  FuncionÃ¡rio Setor Privado    Ensino MÃ©dio Completo
#
#    id_estado estado_civil    raca  qtde_filhos  salario
# 0          2     Solteiro  Branco          2.0     4754
# 1         24       Casado  Branco          1.0     3923
# 2          4   Divorciado  Branco          0.0     1100
# 3         24       Casado   Negro          1.0     1100
# 4         15       Casado   Negro          0.0     3430

# %%
regiao.head()
# Out:
#    id_estado sigla    estado    regiao    pais
# 0          1    AC      Acre     Norte  Brasil
# 1          2    AL   Alagoas  Nordeste  Brasil
# 2          3    AP     Amapá     Norte  Brasil
# 3          4    AM  Amazonas     Norte  Brasil
# 4          5    BA     Bahia  Nordeste  Brasil

# %%
regiao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id_estado  27 non-null     int64
#  1   sigla      27 non-null     object
#  2   estado     27 non-null     object
#  3   regiao     27 non-null     object
#  4   pais       27 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.2+ KB

# %%
pacientes.describe()
# Out:
#         id_cliente        idade    id_estado  qtde_filhos       salario
# count  7999.000000  7999.000000  7999.000000  7989.000000   7999.000000
# mean   4000.000000    38.477060    14.094012     2.405432   3169.312664
# std    2309.256735    13.568667     7.821634     1.703916   3055.862493
# min       1.000000    17.000000     1.000000     0.000000      0.000000
# 25%    2000.500000    28.000000     7.000000     1.000000   1100.000000
# 50%    4000.000000    37.000000    14.000000     2.000000   2410.000000
# 75%    5999.500000    47.000000    21.000000     4.000000   3640.500000
# max    7999.000000    90.000000    27.000000     5.000000  19994.000000

# %%
clinicos.isna().sum()
# Out:
# id_cliente    0
# peso          5
# colesterol    0
# genero        0
# dtype: int64

# %%
pacientes.isna().sum()
# Out:
# id_cliente           0
# idade                0
# classe_trabalho    387
# escolaridade         0
# id_estado            0
# estado_civil         0
# raca                 0
# qtde_filhos         10
# salario              0
# dtype: int64

# %%
regiao.isna().sum()
# Out:
# id_estado    0
# sigla        0
# estado       0
# regiao       0
# pais         0
# dtype: int64

# %%
clinicos.loc[clinicos['peso'].isnull()]
# Out:
#      id_cliente  peso  colesterol     genero
# 63           64   NaN         211  Masculino
# 101         102   NaN         230   Feminino
# 146         147   NaN         171  Masculino
# 195         196   NaN         143   Feminino
# 215         216   NaN         180  Masculino

# %%
pacientes.loc[pacientes['classe_trabalho'].isnull()]
# Out:
#       id_cliente  idade classe_trabalho                   escolaridade  \
# 61            62     32             NaN  Ensino Fundamental Incompleto
# 69            70     25             NaN         Ensino MÃ©dio Completo
# 127          128     35             NaN       Ensino MÃ©dio Incompleto
# 148          149     43             NaN         Ensino MÃ©dio Completo
# 153          154     52             NaN       Ensino MÃ©dio Incompleto
# ...          ...    ...             ...                            ...
# 7931        7932     51             NaN         Ensino MÃ©dio Completo
# 7952        7953     19             NaN         Ensino MÃ©dio Completo
# 7960        7961     30             NaN    Ensino Fundamental Completo
# 7988        7989     20             NaN         Ensino MÃ©dio Completo
# 7996        7997     44             NaN         Ensino MÃ©dio Completo
#
#       id_estado     estado_civil     raca  qtde_filhos  salario
# ...

# %%
clinicos.dropna(subset=['peso'], inplace=True)
pacientes.dropna(subset=['classe_trabalho', 'qtde_filhos'], inplace=True)

# %%
clinicos.isna().sum()
# Out:
# id_cliente    0
# peso          0
# colesterol    0
# genero        0
# dtype: int64

# %%
pacientes.isna().sum()
# Out:
# id_cliente         0
# idade              0
# classe_trabalho    0
# escolaridade       0
# id_estado          0
# estado_civil       0
# raca               0
# qtde_filhos        0
# salario            0
# dtype: int64

# %%
pacientes.count()
# Out:
# id_cliente         7602
# idade              7602
# classe_trabalho    7602
# escolaridade       7602
# id_estado          7602
# estado_civil       7602
# raca               7602
# qtde_filhos        7602
# salario            7602
# dtype: int64

# %%
clinicos.count()
# Out:
# id_cliente    585
# peso          585
# colesterol    585
# genero        585
# dtype: int64

# %%
LE = LabelEncoder()
clinicos['genero'] = LE.fit_transform(clinicos['genero']) #Trnasforma dados da tabela em int (0, 1)

# %%
pacientes

# %%
clinicos_pacientes = pd.merge(clinicos, pacientes, on='id_cliente')
clinicos_pacientes.sort_values('id_cliente')
# Out:
#      id_cliente   peso  colesterol     genero  idade  \
# 0             1  102.0         111  Masculino     39
# 1             2  115.0         135  Masculino     50
# 2             3  115.0         136  Masculino     38
# 3             4  140.0         167   Feminino     53
# 4             5  130.0         158  Masculino     28
# ..          ...    ...         ...        ...    ...
# 538         543  172.0         207  Masculino     46
# 539         544  129.0         157  Masculino     36
# 540         545  107.0         115  Masculino     72
# 541         546  117.0         147  Masculino     35
# 542         547  148.0         176  Masculino     33
#
#                 classe_trabalho              escolaridade  id_estado  \
# 0             Servidor PÃºblico    Ensino MÃ©dio Completo          2
# 1                     AutÃ´nomo       Superior Incompleto         24
# 2    FuncionÃ¡rio Setor Privado  Ensino MÃ©dio Incompleto          4
# ...

# %%
clinicos_pacientes_regiao = pd.merge(clinicos_pacientes, regiao, on='id_estado')
clinicos_pacientes_regiao.sort_values('id_estado')

# %%
clinicos_pacientes_regiao.reset_index(drop=True)

# %%
#clinicos_pacientes_regiao.sigla.str.upper()
#clinicos_pacientes_regiao['sigla'] = clinicos_pacientes_clinicos.sigla.str.upper()    COMANDO PARA DEIXAR TUDO MAIUSCULO

# %%
#clinicos_pacientes_regiao[['id_cliente', 'peso']]  COMANDO PARA ORGANIZAR O DB

# %%
clinicos_pacientes_regiao.to_csv('dbCompleto.csv', index=False)
