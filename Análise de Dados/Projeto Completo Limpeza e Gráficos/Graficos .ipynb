# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
dbCompleto = pd.read_csv('dbCompleto.csv', sep=',' , encoding='latin-1')

# %%
dbCompleto
# Out:
#      id_cliente   peso  colesterol  genero  idade  \
# 0             1  102.0         111       1     39
# 1            27  108.0         123       0     19
# 2           111  131.0         162       1     38
# 3           144  175.0         214       1     70
# 4           153  100.0         107       1     21
# ..          ...    ...         ...     ...    ...
# 538         279  132.0         161       0     24
# 539         281  116.0         141       0     42
# 540         288  174.0         214       0     25
# 541         424  118.0         135       0     36
# 542         502  152.0         178       1     43
#
#                   classe_trabalho                escolaridade  id_estado  \
# 0             Servidor PÃÂºblico    Ensino MÃÂ©dio Completo          2
# 1                   EstagiÃÂ¡rio  Ensino MÃÂ©dio Incompleto          2
# 2    FuncionÃÂ¡rio Setor Privado                    Mestrado          2
# 3                      Aposentado    Ensino MÃÂ©dio Completo          2
# 4    FuncionÃÂ¡rio Setor Privado  Ensino MÃÂ©dio Incompleto          2
# ..                            ...                         ...        ...
# 538  FuncionÃÂ¡rio Setor Privado    Ensino MÃÂ©dio Completo         20
# 539                 EmpresÃÂ¡rio    Ensino MÃÂ©dio Completo         20
# 540  FuncionÃÂ¡rio Setor Privado    Ensino MÃÂ©dio Completo         20
# 541     FuncionÃÂ¡rio PÃÂºblico                    Mestrado         20
# 542  FuncionÃÂ¡rio Setor Privado    Ensino MÃÂ©dio Completo         20
#
#     estado_civil    raca  qtde_filhos  salario sigla               estado  \
# 0       Solteiro  Branco          2.0     4754    AL              Alagoas
# 1       Solteiro  Branco          2.0     1100    AL              Alagoas
# 2         Casado  Branco          4.0     6836    AL              Alagoas
# 3       Solteiro  Branco          4.0     2616    AL              Alagoas
# 4       Solteiro  Branco          3.0     1100    AL              Alagoas
# ..           ...     ...          ...      ...   ...                  ...
# 538       Casado  Branco          2.0     3627    RN  Rio Grande do Norte
# 539       Casado  Branco          1.0     6407    RN  Rio Grande do Norte
# 540     Solteiro  Branco          4.0     2759    RN  Rio Grande do Norte
# 541     Solteiro  Branco          4.0     7855    RN  Rio Grande do Norte
# 542       Casado  Branco          4.0     3503    RN  Rio Grande do Norte
#
#        regiao    pais
# 0    Nordeste  Brasil
# 1    Nordeste  Brasil
# 2    Nordeste  Brasil
# 3    Nordeste  Brasil
# 4    Nordeste  Brasil
# ..        ...     ...
# 538  Nordeste  Brasil
# 539  Nordeste  Brasil
# 540  Nordeste  Brasil
# 541  Nordeste  Brasil
# 542  Nordeste  Brasil
#
# [543 rows x 16 columns]

# %%
dados_cliente = dbCompleto[['peso', '', 'idade']]
dados_cliente.head()
# Out:
#     peso  colesterol  idade
# 0  102.0         111     39
# 1  108.0         123     19
# 2  131.0         162     38
# 3  175.0         214     70
# 4  100.0         107     21

# %%
sudeste = dbCompleto[dbCompleto['regiao'] == 'Sudeste']

plt.hist(sudeste['idade'], bins=20)
plt.xlabel('Idade')
plt.ylabel('Número de Pacientes')
plt.title('Distribuição das Idades de Pacientes na Região Sudeste')
plt.show()

# %%
sns.scatterplot(x='salario', y='idade', hue='genero', data=dbCompleto)

plt.title('Relação entre Idade e Salário por Gênero')
plt.xlabel('Salário')
plt.ylabel('Idade')

plt.show()

# %%
nordeste = dbCompleto[dbCompleto['regiao'] == 'Nordeste']

mediaSalarialNordeste = nordeste['salario'].mean()

print("A média salarial na região Nordeste é:", mediaSalarialNordeste)
# Out:
# A média salarial na região Nordeste é: 3433.313953488372

# %%
nordeste = dbCompleto[dbCompleto['regiao'] == 'Nordeste']

mediaIdadePorEstado = nordeste.groupby('estado')['idade'].mean()

estadoMaiorMedia = mediaIdadePorEstado.idxmax()

print("O estado do Nordeste com a maior média de idade é:", estadoMaiorMedia)
# Out:
# O estado do Nordeste com a maior média de idade é: PiauÃ­

# %%
mediaIdadePorEstado.plot(kind='bar')
plt.title('Média de Idade por Estado do Nordeste')
plt.xlabel('Estado')
plt.ylabel('Média de Idade')
plt.show()

# %%
pacientesMestrado = dbCompleto[dbCompleto['escolaridade'] == 'Mestrado']

contagemPorEstado = pacientesMestrado['estado'].value_counts()

estadoMaiorContagem = contagemPorEstado.idxmax()

print("O estado com o maior número de pacientes com mestrado é:", estadoMaiorContagem)
# Out:
# O estado com o maior número de pacientes com mestrado é: Santa Catarina

# %%
contagemPorEstado.plot(kind='bar')
plt.title('Número de Pacientes com Mestrado por Estado')
plt.xlabel('Estado')
plt.ylabel('Número de Pacientes')
plt.show()

# %%
plt.plot(range(1, 11), wcss)
plt.title('Método do Cotovelo')
plt.xlabel('Número de Clusters')
plt.ylabel('WCSS')
plt.show()

wcssTerceiroCluster = round(wcss[2], 3)  
print("O valor de WCSS para o terceiro cluster é:", wcssTerceiroCluster)
# Out:
# O valor de WCSS para o terceiro cluster é: 138862.206

# %%
dbCompleto['id_cliente'] = np.where(dbCompleto['id_cliente'] == 1, 'Risco Baixo',
                                 np.where(dbCompleto['id_cliente'] == 2, 'Risco Moderado', 'Risco Alto'))

sns.scatterplot(data=dbCompleto,  
                x='peso',  
                y='colesterol',  
                hue='id_cliente',  
                palette={'Risco Baixo': 'red',  
                         'Risco Moderado': 'green',  
                         'Risco Alto': 'blue'})
# Out:
# <AxesSubplot:xlabel='peso', ylabel='colesterol'>
