# %%
import json
import csv

# %%
with open('C:\Projetos-Pessoais-e-Material-de-Consulta\Meu Historico Spotify\Streaming_History_Video_2022-2025.json', 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)


if isinstance(data, list) and all(isinstance(item, dict) for item in data):

    csv_file = 'arquivo.csv'
    
    headers = data[0].keys()
    
    with open(csv_file, 'w', encoding='utf-8', newline='') as csv_output:
        writer = csv.DictWriter(csv_output, fieldnames=headers)
        writer.writeheader()
        writer.writerows(data)
    
    print(f"Arquivo CSV salvo como '{csv_file}'.")
else:
    print("O JSON não está em um formato compatível (lista de dicionários).")
# Out:
# Arquivo CSV salvo como 'arquivo.csv'.
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\conta\AppData\Local\Temp\ipykernel_22960\3525410268.py:1: SyntaxWarning: invalid escape sequence '\P'
#   with open('C:\Projetos-Pessoais-e-Material-de-Consulta\Meu Historico Spotify\Streaming_History_Video_2022-2025.json', 'r', encoding='utf-8') as json_file:
