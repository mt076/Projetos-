# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
vendas_Limpo = pd.read_excel("C:/Users/conta/Desktop/Projeto D3.js/vendas_Limpo.xlsx")

# %%
vendas_Limpo.head(10)
# Out:
#          ID_Pedido ID_Cliente     Segmento           Regiao           Pais  \
# 0   CA-2012-124891   RH-19495   Consumidor         New York  United States
# 1    IN-2013-77878   JR-16210  Corporativo  New South Wales      Australia
# 2    IN-2013-71249   CR-12730   Consumidor       Queensland      Australia
# 3  ES-2013-1579342   KM-16375  Home Office           Berlin        Germany
# 4     SG-2013-4320    RH-9495   Consumidor            Dakar        Senegal
# 5    IN-2013-42360   JM-15655  Corporativo  New South Wales      Australia
# 6    IN-2011-81826   TS-21340   Consumidor       Wellington    New Zealand
# 7    IN-2012-86369   MB-18085   Consumidor          Waikato    New Zealand
# 8   CA-2014-135909   JW-15220  Corporativo       California  United States
# 9   CA-2012-116638   JH-15985   Consumidor   North Carolina  United States
#
#          Product ID    Categoria SubCategoria  Total_Vendas  Quantidade  \
# ...

# %%
vendas_Limpo_100.describe()
# Out:
#        Total_Vendas  Quantidade    Desconto        Lucro          Ano
# count    100.000000  100.000000  100.000000   100.000000   100.000000
# mean    3263.366316    6.840000    0.066600   662.777417  2012.690000
# std     1487.837655    2.880516    0.106013   983.863172     1.125418
# min     1487.400000    2.000000    0.000000 -3839.990400  2011.000000
# 25%     2195.137500    5.000000    0.000000   149.164200  2012.000000
# 50%     2883.397500    6.000000    0.000000   573.375000  2013.000000
# 75%     3933.165000    9.000000    0.100000  1006.380000  2014.000000
# max     9449.950000   14.000000    0.500000  4630.475500  2014.000000

# %%
vendas_Limpo_100 = vendas_Limpo.head(100)

# %%
'''vendas_Limpo = vendas_Limpo.groupby('Pais')['Total_Vendas'].sum().reset_index()'''

plt.figure(figsize=(10, 6))
plt.bar(vendas_Limpo_100['Segmento'], vendas_Limpo_100['Total_Vendas'], color = 'Green')

'''plt.title('Titulo')'''
plt.xlabel('Publico Alvo')
plt.ylabel('Total de Vendas')

plt.xticks(rotation=45)

plt.show()

# %%
x = vendas_Limpo_100['Ano'].astype(int)
y = vendas_Limpo_100['Total_Vendas']

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(x, y, color='black')

plt.title('Total de Vendas por ANO')
plt.xlabel('Ano')
plt.ylabel('Total de Vendas')

plt.show()

# %%
data = vendas_Limpo_100['Ano']
names = vendas_Limpo_100['Categoria']
values = vendas_Limpo_100['Total_Vendas']

fig, axs = plt.subplots(1, 3, figsize=(14, 5), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')
