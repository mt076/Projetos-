# %%
import pandas as pd 
import numpy as np

# %%
vendas = pd.read_excel("C:/Users/conta/Desktop/Projeto D3.js/vendas.xlsx")

# %%
print(vendas.isnull().sum())
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Regiao          0
# Pais            0
# Product ID      0
# Categoria       0
# SubCategoria    0
# Total_Vendas    0
# Quantidade      0
# Desconto        0
# Lucro           0
# Prioridade      0
# dtype: int64

# %%
vendas.describe()
# Out:
#        Total_Vendas    Quantidade      Desconto         Lucro
# count  51290.000000  51290.000000  51290.000000  51290.000000
# mean     246.490581      3.476545      0.142908     28.610982
# std      487.565361      2.278766      0.212280    174.340972
# min        0.444000      1.000000      0.000000  -6599.978000
# 25%       30.758625      2.000000      0.000000      0.000000
# 50%       85.053000      3.000000      0.000000      9.240000
# 75%      251.053200      5.000000      0.200000     36.810000
# max    22638.480000     14.000000      0.850000   8399.976000

# %%
vendas.head(10)
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Regiao  \
# 0   CA-2012-124891  31-07-2012   RH-19495   Consumidor         New York
# 1    IN-2013-77878  05-02-2013   JR-16210  Corporativo  New South Wales
# 2    IN-2013-71249  17-10-2013   CR-12730   Consumidor       Queensland
# 3  ES-2013-1579342  28-01-2013   KM-16375  Home Office           Berlin
# 4     SG-2013-4320  05-11-2013    RH-9495   Consumidor            Dakar
# 5    IN-2013-42360  28-06-2013   JM-15655  Corporativo  New South Wales
# 6    IN-2011-81826  07-11-2011   TS-21340   Consumidor       Wellington
# 7    IN-2012-86369  14-04-2012   MB-18085   Consumidor          Waikato
# 8   CA-2014-135909  14-10-2014   JW-15220  Corporativo       California
# 9   CA-2012-116638  28-01-2012   JH-15985   Consumidor   North Carolina
#
#             Pais        Product ID    Categoria SubCategoria  Total_Vendas  \
# 0  United States   TEC-AC-10003033   Tecnologia  Accessories      2309.650
# ...

# %%
vendas['Data_Pedido'] = pd.to_datetime(vendas['Data_Pedido'], format='%d-%m-%Y')

vendas['Mes'] = vendas['Data_Pedido'].dt.month
vendas['Ano'] = vendas['Data_Pedido'].dt.year

vendas.head(10)
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Regiao  \
# 0   CA-2012-124891  2012-07-31   RH-19495   Consumidor         New York
# 1    IN-2013-77878  2013-02-05   JR-16210  Corporativo  New South Wales
# 2    IN-2013-71249  2013-10-17   CR-12730   Consumidor       Queensland
# 3  ES-2013-1579342  2013-01-28   KM-16375  Home Office           Berlin
# 4     SG-2013-4320  2013-11-05    RH-9495   Consumidor            Dakar
# 5    IN-2013-42360  2013-06-28   JM-15655  Corporativo  New South Wales
# 6    IN-2011-81826  2011-11-07   TS-21340   Consumidor       Wellington
# 7    IN-2012-86369  2012-04-14   MB-18085   Consumidor          Waikato
# 8   CA-2014-135909  2014-10-14   JW-15220  Corporativo       California
# 9   CA-2012-116638  2012-01-28   JH-15985   Consumidor   North Carolina
#
#             Pais        Product ID    Categoria SubCategoria  Total_Vendas  \
# 0  United States   TEC-AC-10003033   Tecnologia  Accessories      2309.650
# ...

# %%
'''Deletando conlunas'''
vendas = vendas.drop(columns=['Data_Pedido'])

# %%
meses = {
    1: 'Janeiro', 2: 'Fevereiro', 3: 'Março', 4: 'Abril',
    5: 'Maio', 6: 'Junho', 7: 'Julho', 8: 'Agosto',
    9: 'Setembro', 10: 'Outubro', 11: 'Novembro', 12: 'Dezembro'
}

vendas['Mes'] = vendas['Data_Pedido'].dt.month.map(meses)

# %%
vendas.head(10)
# Out:
#          ID_Pedido ID_Cliente     Segmento           Regiao           Pais  \
# 0   CA-2012-124891   RH-19495   Consumidor         New York  United States
# 1    IN-2013-77878   JR-16210  Corporativo  New South Wales      Australia
# 2    IN-2013-71249   CR-12730   Consumidor       Queensland      Australia
# 3  ES-2013-1579342   KM-16375  Home Office           Berlin        Germany
# 4     SG-2013-4320    RH-9495   Consumidor            Dakar        Senegal
# 5    IN-2013-42360   JM-15655  Corporativo  New South Wales      Australia
# 6    IN-2011-81826   TS-21340   Consumidor       Wellington    New Zealand
# 7    IN-2012-86369   MB-18085   Consumidor          Waikato    New Zealand
# 8   CA-2014-135909   JW-15220  Corporativo       California  United States
# 9   CA-2012-116638   JH-15985   Consumidor   North Carolina  United States
#
#          Product ID    Categoria SubCategoria  Total_Vendas  Quantidade  \
# ...

# %%
vendas.to_excel('vendas_Limpo.xlsx', index=False)
